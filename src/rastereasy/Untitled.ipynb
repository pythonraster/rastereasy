# %%
import rastereasy

# %%
im=rastereasy.Geoimage('/Users/corpetti/tmpo/sentinel.tif')

# %%
im.plot_spectra()
# Out:
# Label(value='Click on the image to retrieve spectra.')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ([], [], [])
